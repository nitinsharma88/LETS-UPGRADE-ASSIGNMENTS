# %%
NAME -Nitin kumar sharma
Mobile-9873147995
email- nitinsharma882000@gmail.com

# %%
ANSWER1- OPTION C - RAINBOW

# %%
#ANSWER 2
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
#ANSWER3
cp= int(input())
sp= int(input())
if cp>sp:
    print("Loss")
elif cp<sp:
    print("Profit")    
else:
    print("Neither")
# Out:
#  20
#  30
# Profit

# %%
#ANSWER 4
x= int(input())
print(x*80)
# Out:
#  20
# 1600
